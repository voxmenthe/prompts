# %% [markdown]
# image.png

# %% [markdown]
# image.png

# %%
from IPython.display import display, Image
display(Image("vibe_coding.jpeg"))

# %% [markdown]
# from IPython.display import display, Image
# display(Image("image.png"))
